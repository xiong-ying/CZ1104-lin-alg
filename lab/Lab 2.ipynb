# %% [markdown]
# # Exercise 1
# ### Question 1: Use the code available in NTULearn to plot these points. Note the application of Identity transformation in the code.

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 Identity transformation matrix
I = np.eye(3) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (1,1,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ___
# ### Question 2: Modify the above code to implement and the display the results of the following transformations:
# (i) scaling transformation with scale of 2,

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 Scaling transformation matrix
I = np.array([(2, 0, 0), (0, 2, 0), (0, 0, 1)]) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (1,1,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ---
# (ii) rotation transformation with 90°

# %%
import matplotlib.pyplot as plt
import numpy as np
import string
import math

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 rotation transformation matrix
angle = math.pi/2
I = np.array([(math.cos(angle), math.sin(angle), 0), (-math.sin(angle), math.cos(angle), 0), (0, 0, 1)]) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (0,0,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-2.5, 3, 0.5))
ax.set_yticks(np.arange(-2.5, 3, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ---
# (iii) translation

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 translation transformation matrix, parameter is 3
I = np.array([(1, 0, 3), 
              (0, 1, 3), 
              (0, 0, 1)]) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (1,1,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(0, 5, 0.5))
ax.set_yticks(np.arange(0, 5, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ---
# (iv) horizontal shear

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 horizontal shear transformation matrix, parameter is 3
I = np.array([(1, 3, 0), 
              (0, 1, 0), 
              (0, 0, 1)]) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (1,1,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-4, 4, 0.5))
ax.set_yticks(np.arange(-4, 4, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ---
# (v) vertical shear

# %%
import matplotlib.pyplot as plt
import numpy as np
import string

# points a, b and, c
a, b, c, d = (0, 1, 0), (1, 0, 1), (0, -1, 2), (-1, 0, 3)

# matrix with row vectors of points
A = np.array([a, b, c, d])

# 3x3 vertical shear transformation matrix, parameter is 3
I = np.array([(1, 0, 0), 
              (3, 1, 0), 
              (0, 0, 1)]) #float

color_lut = 'rgbc' #4 colors to represent 4 points

fig = plt.figure()
ax = plt.gca()
xs = []
ys = []
for row in A:
    #print(row)
    m = np.array([(row[0],row[0],0), (row[1],row[1],0), (1,1,row[2])])
    #print(m)
    output_row = I @ m
    #print(output_row)
    x, y, i = output_row[0][0], output_row[1][1], output_row[2][2]
    xs.append(x)
    ys.append(y)
    i = int(i) # convert float to int for indexing
    c = color_lut[i]
    plt.scatter(x, y, color=c)
    plt.text(x + 0.15, y, f"{string.ascii_letters[i]}")
xs.append(xs[0])
ys.append(ys[0])
plt.plot(xs, ys, color="gray", linestyle='dotted')
ax.set_xticks(np.arange(-4, 4, 0.5))
ax.set_yticks(np.arange(-4, 4, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# ---
# # Exercise 2
# ### Question 4

# %%
import numpy as np

'''Function to transform a matrix to reduced row echelon form'''
def rref(A):
    tol = 1e-16
    #A = B.copy()
    rows, cols = A.shape
    r = 0
    pivots_pos = []
    row_exchanges = np.arange(rows)
    for c in range(cols):
        ## Find the pivot row:
        pivot = np.argmax (np.abs (A[r:rows,c])) + r
        m = np.abs(A[pivot, c])
        if m <= tol:
        ## Skip column c, making sure the approximately zero terms are
        ## actually zero.
            A[r:rows, c] = np.zeros(rows-r)
        else:
            ## keep track of bound variables
            pivots_pos.append((r,c))

            if pivot != r:
                ## Swap current row and pivot row
                A[[pivot, r], c:cols] = A[[r, pivot], c:cols]
                row_exchanges[[pivot,r]] = row_exchanges[[r,pivot]]

            ## Normalize pivot row
            A[r, c:cols] = A[r, c:cols] / A[r, c];

            ## Eliminate the current column
            v = A[r, c:cols]
            ## Above (before row r):
            if r > 0:
                ridx_above = np.arange(r)
                A[ridx_above, c:cols] = A[ridx_above, c:cols] - np.outer(v, A[ridx_above, c]).T
                ## Below (after row r):
            if r < rows-1:
                ridx_below = np.arange(r+1,rows)
                A[ridx_below, c:cols] = A[ridx_below, c:cols] - np.outer(v, A[ridx_below, c]).T
                r += 1
        ## Check if done
        if r == rows:
            break;
    return A

# %%
from fractions import Fraction

oneThird = Fraction(1,3)
oneHalf = Fraction(1,2)

# L
L = np.array([(0, oneThird, oneThird, oneHalf), 
              (oneHalf, 0, oneThird, 0), 
              (oneHalf, oneThird,  0, oneHalf), 
              (0, oneThird, oneThird, 0)])

# L - I | 0
L1 = np.array([(-1,     oneThird,  oneThird,  oneHalf, 0), 
              (oneHalf, -1,        oneThird,  0,       0), 
              (oneHalf, oneThird,  -1,        oneHalf, 0), 
              (0,       oneThird,  oneThird,  -1,      0)])

print("Reduced row echelon form of [ (L-I)|0 ]:")
print(rref(L1))
# Out:
# Reduced row echelon form of [ (L-I)|0 ]:
# [[1.0 Fraction(0, 1) Fraction(0, 1) Fraction(-3, 2) -0.0]
#  [0.0 Fraction(1, 1) Fraction(0, 1) Fraction(-21, 16) -0.0]
#  [0.0 Fraction(0, 1) Fraction(1, 1) Fraction(-27, 16) -0.0]
#  [0.0 Fraction(0, 1) Fraction(0, 1) 0.0 0.0]]

# %% [markdown]
# According to the reduce row echelon form:<br>
# [[1, 0, 0, -3/2, 0],<br>
# [0, 1, 0, -21/16, 0],<br>
#  [0, 0, 1, -27/16, 0],<br>
#  [0, 0, 0, 0, 0]]<br>
# <br>
# We can get the following equations: <br>
#  ra * 1 + rd * (-3/2) = 0<br>
#  rb + rd * (-21/16) = 0<br>
#  rc + rd * (-27/16) = 0 <br>
#
#  Set rd = 1, <br>
#  Then

# %%
rd = 1
rc = Fraction(27,16)
rb = Fraction(21,16)
ra = Fraction(3,2)

print("The value of ra, rb, rc, rd is: ")
print("ra =", ra)
print("rb =", rb)
print("rc =", rc)
print("rd =", rd)
# Out:
# The value of ra, rb, rc, rd is:
# ra = 3/2
# rb = 21/16
# rc = 27/16
# rd = 1

# %% [markdown]
# (a) the equation Lr=r alwasy have a solution.
# Because (L-I)r=0 is a homogenous system, will at least have the trivial solution.
# <br>
# (b) The solution have entries that are nonnegative.
# <br>
# (c) The solution might not be unique, but can set arbitrary number to compare

# %% [markdown]
# ---
# ### Question 5

# %%
oneForth = Fraction(1,4)
oneThird = Fraction(1,3)
oneHalf = Fraction(1,2)
one = Fraction(1,1)

# L
L = np.array([(0, oneHalf, oneForth, one, oneThird), 
              (oneThird, 0, oneForth, 0, 0), 
              (oneThird, oneHalf, 0, 0, oneThird), 
              (oneThird, 0, oneForth, 0, oneThird),
              (0, 0, oneForth, 0, 0)])

# L - I | 0
L1 = np.array([(-one,    oneHalf, oneForth, one,  oneThird, 0), 
              (oneThird, -one,    oneForth, 0,    0,        0), 
              (oneThird, oneHalf, -one,     0,    oneThird, 0), 
              (oneThird, 0,       oneForth, -one, oneThird, 0),
              (0,        0,       oneForth, 0,    -one,     0)])

print("Reduced row echelon form of [ (L-I)|0 ]:")
print(rref(L1))
# Out:
# Reduced row echelon form of [ (L-I)|0 ]:
# [[Fraction(1, 1) Fraction(0, 1) Fraction(0, 1) Fraction(0, 1)
#   Fraction(-19, 3) Fraction(0, 1)]
#  [Fraction(0, 1) Fraction(1, 1) Fraction(0, 1) Fraction(0, 1)
#   Fraction(-28, 9) Fraction(0, 1)]
#  [Fraction(0, 1) Fraction(0, 1) Fraction(1, 1) Fraction(0, 1)
#   Fraction(-4, 1) Fraction(0, 1)]
#  [Fraction(0, 1) Fraction(0, 1) Fraction(0, 1) Fraction(1, 1)
#   Fraction(-31, 9) Fraction(0, 1)]
#  [Fraction(0, 1) Fraction(0, 1) Fraction(0, 1) Fraction(0, 1) 0.0 0.0]]

# %% [markdown]
# According to the reduce row echelon form:<br>
# [[1, 0, 0, 0, -19/3, 0],<br>
# [0, 1, 0, 0, -28/9, 0],<br>
#  [0, 0, 1, 0, -4, 0],<br>
#  [0, 0, 0, 1, -31/9, 0],<br>
#  [0, 0, 0, 0, 0, 0]]<br>
# <br>
# We can get the following equations: <br>
# xA + xE * (-19/3) = 0<br>
# xB + xE * (-28/9) = 0<br>
# xC + xE * (-4) = 0 <br>
# xD + xE * (-31/9) = 0<br>
#
#  Set arbitary value for xE = 1, <br>
#  Then

# %%
xE = 1
xD = Fraction(31,9)
xC = 4
xB = Fraction(28,9)
xA = Fraction(19,3)

print("The value of xA, xB, xC, xD, xE is: ")
print("xA =", xA)
print("xB =", xB)
print("xC =", xC)
print("xD =", xD)
print("xE =", xE)
# Out:
# The value of xA, xB, xC, xD, xE is:
# xA = 19/3
# xB = 28/9
# xC = 4
# xD = 31/9
# xE = 1

# %% [markdown]
# ---
# # Exercise 3
# ### Question 6

# %% [markdown]
# According to the question,
# x = [S, I, R, D]<br>
#
# The next day, x will becomes <br>
# x1 = [0.95 * S + 0.04 * I, 0.05 * S + 0.85 * I, 0.1 * I + R, 0.01 * I + D] <br>
#
# = [0.95, 0.05, 0, 0] * S + [0.04, 0.85, 0.1, 0.1] * I + [0, 0, 1, 0] * R +[0, 0, 0, 1] * D<br>
#
# Becuase, x1 = P * x ,  <br>

# %%
# P matrix is:
P = np.array([(0.95, 0.04, 0, 0), 
              (0.05, 0.85, 0, 0), 
              (0, 0.1, 1, 0), 
              (0, 0.01, 0, 1)])

# knowing that xt is:
xt = np.array([0.75, 0.1, 0.1, 0.05])

# We can easity obtain x(t+1) = P multiple xt
xt1 = P @ xt

print("The matrix P containing the stated transformation is:")
print(P)
print()
print("The state of disease the next day is:")
print(xt1)
# Out:
# The matrix P containing the stated transformation is:
# [[0.95 0.04 0.   0.  ]
#  [0.05 0.85 0.   0.  ]
#  [0.   0.1  1.   0.  ]
#  [0.   0.01 0.   1.  ]]
#
# The state of disease the next day is:
# [0.7165 0.1225 0.11   0.051 ]

# %% [markdown]
# ---
# ### Question 7

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# initialize arrays
x1 = np.array([1, 0, 0, 0])
t = np.array([])
S = np.array([])
I = np.array([])
R = np.array([])
D = np.array([])

# Calculate the progression and store in each array
for i in range (201):
    
    t = np.append(t, i)
    S = np.append(S, x1[0])
    I = np.append(I, x1[1])
    R = np.append(R, x1[2])
    D = np.append(D, x1[3])
    
    x1 = P @ x1

# outcome and plot the graph
print("The progression of SIRD from day 1 to day 200")

# multiple line plots
plt.plot( t, S, color='blue', linewidth=2, label="Susceptible S(t)")
plt.plot( t, I, color='red', linewidth=2, label="Infected I(t)")
plt.plot( t, R, color='green', linewidth=2, label="Recovered R(t)")
plt.plot( t, D, color='black', linewidth=2, label="Deceased D(t)")

# show legend
plt.legend()

# show graph
plt.show()
# Out:
# The progression of SIRD from day 1 to day 200
